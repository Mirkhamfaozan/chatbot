# %% [markdown]
# # 1. Import Library yang kita butuhkan
#
# - Pada perintah di bawah kami mengimport semua kebutuhan library yang kami butuhkan,
# - Jika temen temen tidak mau import semua library yang di butuhkan dalam step 1 temen temen cukup import library json saja untuk menghubungkan dataset yang sudah kita buat.
#
# ### Perlu di note sebelumnya di virtual environment kami sudah Install and import library yang di butuhkan seperti **tensorflow, keras, keras-models, pickle, nltk**
#
# Cara install:
#
# - pip install tensorflow
# - pip install keras
# - pip install keras-models
# - pip install pickle
# - pip install nltk

# %%
# import necessary libraries
import warnings
warnings.filterwarnings("ignore")
import nltk
from nltk.stem import WordNetLemmatizer
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from keras.models import load_model

# create an object of WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# importing the GL Bot corpus file for pre-processing

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open("data.json").read()
intents = json.loads(data_file)

# %% [markdown]
# # 2. Data pre-processing

# %%
# preprocessing the json data
# tokenization
#nltk.download('punkt')
#nltk.download('wordnet')
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %% [markdown]
# ### Tokenisasi
#
# - Pada proses tokenisasi pada dasarnya adalah pemisahan kalimat, paragraf,
# atau seluruh dokumen teks menjadi unit yang lebih kecil, proses itu yang disebut token
#
# - Pada proses ini juga akan save documen tersebut menjadi file label.pkl dan texts.pkl (proses labeling)

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# sort classes
classes = sorted(list(set(classes)))

# documents = combination between patterns and intents
print (len(documents), "documents")

# classes = intents
print (len(classes), "classes", classes)

# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

# creating a pickle file to store the Python objects which we will use while predicting
pickle.dump(words,open('texts.pkl','wb')) 
pickle.dump(classes,open('labels.pkl','wb'))
# Out:
# 50 documents
# 13 classes ['bye', 'dasar', 'kemampuan', 'komunitas', 'kustomisasi', 'logo', 'nama', 'pekerjaan', 'pewarnaan', 'salam', 'sapa', 'skema', 'web']
# 97 unique lemmatized words ['ada', 'aja', 'anda', 'apa', 'apakah', 'atau', 'bagaimana', 'bantu', 'bantuin', 'biru', 'bisa', 'bye', 'cara', 'cocok', 'color', 'colormatch', 'daah', 'dadah', 'dah', 'dalam', 'dasar', 'dengan', 'di', 'dikombinasikan', 'disesuaikan', 'fitur', 'ga', 'gelap', 'grup', 'grupnya', 'hai', 'halo', 'harimu', 'hello', 'hi', 'hijau', 'hitam', 'ini', 'jika', 'jumpa', 'kabar', 'kalau', 'kamu', 'kaos', 'kemampuan', 'kemana', 'kerja', 'komunitasnya', 'kustomisasi', 'lagi', 'lakukan', 'lo', 'logo', 'lu', 'makasih', 'malam', 'mau', 'memilih', 'menarik', 'menyenangkan', 'merah', 'model', 'nama', 'nanya', 'ngapain', 'nya', 'ok', 'oleh', 'p', 'pada', 'pagi', 'pekerjaan', 'pengguna', 'ping', 'putih', 'saja', 'salam', 'sampai', 'sape', 'selamat', 'semoga', 'siang', 'siapa', 'sih', 'skema', 'tanya-tanya', 'teks', 'tidak', 'tinggal', 'tugas', 'ukuran', 'variasi', 'warna', 'warnain', 'web', 'ya', 'yang']

# %% [markdown]
# # 3. Creating Training Data
#
# - Pada dasarnya, bag of words adalah representasi sederhana dari setiap teks dalam sebuah kalimat sebagai bag of words-nya.

# %%
#KODINGAN SALAHHH


# create our training data
training = []

# create an empty array for our output
output_empty = [0] * len(classes)

# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
   
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

# shuffle features and converting it into numpy arrays
random.shuffle(training)
training = np.array(training)

# create train and test lists
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Training data created")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8264/2698011779.py in <module>
#      50
#      51 random.shuffle(training)
# ---> 52 training_data = np.array(training)
#      53
#      54 train_x = np.array([i[0] for i in training_data])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (100, 2) + inhomogeneous part.

# %%
#KODINGAN BENER

# create our training data
training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append(bag + output_row)  # Gabungkan bag dan output_row menjadi satu list

random.shuffle(training)
training_data = np.array(training)

train_x = training_data[:, :len(words)]  # Bagian bag (bag of words)
train_y = training_data[:, len(words):]  # Bagian output_row

print("Training data created")
# Out:
# Training data created

# %% [markdown]
# # 5. Creating Modeling
#
# - Pada proses ini kami akan membuat model jaringan saraf dan menyimpan model tersebut

# %%
#KODINGAN SALAHHH

# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('models.h5', hist) # we will pickle this model to use in the future
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8264/4008441374.py in <module>
#       8
#       9 # Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
# ---> 10 sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#      11 model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#      12
#
# c:\Users\IRKHAM\anaconda3\lib\site-packages\keras\src\optimizers\sgd.py in __init__(self, learning_rate, momentum, nesterov, weight_decay, clipnorm, clipvalue, global_clipnorm, use_ema, ema_momentum, ema_overwrite_frequency, jit_compile, name, **kwargs)
#     112         **kwargs
#     113     ):
# --> 114         super().__init__(
#     115             name=name,
#     116             weight_decay=weight_decay,
#
# c:\Users\IRKHAM\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py in __init__(self, name, weight_decay, clipnorm, clipvalue, global_clipnorm, use_ema, ema_momentum, ema_overwrite_frequency, jit_compile, **kwargs)
#    1082         mesh = kwargs.pop("mesh", None)
#    1083         self._mesh = mesh
# -> 1084         super().__init__(
#    1085             name,
#    1086             weight_decay,
#
# c:\Users\IRKHAM\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py in __init__(self, name, weight_decay, clipnorm, clipvalue, global_clipnorm, use_ema, ema_momentum, ema_overwrite_frequency, jit_compile, **kwargs)
#     104         self._variables = []
#     105         self._create_iteration_variable()
# --> 106         self._process_kwargs(kwargs)
#     107
#     108     def _create_iteration_variable(self):
#
# c:\Users\IRKHAM\anaconda3\lib\site-packages\keras\src\optimizers\optimizer.py in _process_kwargs(self, kwargs)
#     133         for k in kwargs:
#     134             if k in legacy_kwargs:
# --> 135                 raise ValueError(
#     136                     f"{k} is deprecated in the new Keras optimizer, please "
#     137                     "check the docstring for valid arguments, or use the "
#
# ValueError: decay is deprecated in the new Keras optimizer, please check the docstring for valid arguments, or use the legacy optimizer, e.g., tf.keras.optimizers.legacy.SGD.

# %%
#KODINGAN BENERRRR

from tensorflow.keras.optimizers import legacy

# Create NN model to predict the responses
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model using the legacy optimizer
sgd = legacy.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=300, batch_size=5, verbose=1)
model.save('models.h5', hist)  # Saving the model for future use
print("\n")
print("*"*50)
print("\nModel Created Successfully!")
# Out:
# Epoch 1/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5492 - accuracy: 0.1400
# Epoch 2/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3821 - accuracy: 0.2000
# Epoch 3/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.3607 - accuracy: 0.3200
# Epoch 4/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2618 - accuracy: 0.2800
# Epoch 5/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1349 - accuracy: 0.3600
# Epoch 6/300
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0756 - accuracy: 0.3600
# Epoch 7/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9347 - accuracy: 0.4200
# Epoch 8/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7711 - accuracy: 0.5800
# Epoch 9/300
# 10/10 [==============================] - 0s 3ms/step - loss: 1.6357 - accuracy: 0.5000
# Epoch 10/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5816 - accuracy: 0.5400
# Epoch 11/300
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5091 - accuracy: 0.5800
# Epoch 12/300
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2276 - accuracy: 0.7000
# Epoch 13/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3457 - accuracy: 0.6000
# Epoch 14/300
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2195 - accuracy: 0.5600
# Epoch 15/300
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0239 - accuracy: 0.6800
# Epoch 16/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9500 - accuracy: 0.7600
# Epoch 17/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8894 - accuracy: 0.7400
# Epoch 18/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8543 - accuracy: 0.7600
# Epoch 19/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8953 - accuracy: 0.7400
# Epoch 20/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6270 - accuracy: 0.9000
# Epoch 21/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6997 - accuracy: 0.8200
# Epoch 22/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5731 - accuracy: 0.8600
# Epoch 23/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5219 - accuracy: 0.8400
# Epoch 24/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5886 - accuracy: 0.8600
# Epoch 25/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4543 - accuracy: 0.9600
# Epoch 26/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5954 - accuracy: 0.8000
# Epoch 27/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5695 - accuracy: 0.7800
# Epoch 28/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5281 - accuracy: 0.8000
# Epoch 29/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4469 - accuracy: 0.8800
# Epoch 30/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4253 - accuracy: 0.8800
# Epoch 31/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3828 - accuracy: 0.9000
# Epoch 32/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3471 - accuracy: 0.9200
# Epoch 33/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3425 - accuracy: 0.8800
# Epoch 34/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3313 - accuracy: 0.9200
# Epoch 35/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2786 - accuracy: 0.9800
# Epoch 36/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4162 - accuracy: 0.9200
# Epoch 37/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3391 - accuracy: 0.9400
# Epoch 38/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3690 - accuracy: 0.8800
# Epoch 39/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.9000
# Epoch 40/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3758 - accuracy: 0.9000
# Epoch 41/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2894 - accuracy: 0.9000
# Epoch 42/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1879 - accuracy: 1.0000
# Epoch 43/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2610 - accuracy: 0.9200
# Epoch 44/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2269 - accuracy: 0.9600
# Epoch 45/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 1.0000
# Epoch 46/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2068 - accuracy: 0.9400
# Epoch 47/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1055 - accuracy: 0.9800
# Epoch 48/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1690 - accuracy: 0.9800
# Epoch 49/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9600
# Epoch 50/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9600
# Epoch 51/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 0.9800
# Epoch 52/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1350 - accuracy: 0.9600
# Epoch 53/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9400
# Epoch 54/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1234 - accuracy: 1.0000
# Epoch 55/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.9400
# Epoch 56/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2095 - accuracy: 0.9400
# Epoch 57/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2221 - accuracy: 0.9000
# Epoch 58/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1433 - accuracy: 0.9600
# Epoch 59/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0867 - accuracy: 0.9800
# Epoch 60/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0875 - accuracy: 1.0000
# Epoch 61/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3285 - accuracy: 0.9000
# Epoch 62/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 63/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.9200
# Epoch 64/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.9600
# Epoch 65/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9600
# Epoch 66/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0977 - accuracy: 0.9600
# Epoch 67/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9800
# Epoch 68/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0860 - accuracy: 0.9800
# Epoch 69/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2167 - accuracy: 0.9200
# Epoch 70/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0686 - accuracy: 0.9800
# Epoch 71/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1349 - accuracy: 0.9800
# Epoch 72/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1080 - accuracy: 0.9800
# Epoch 73/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0813 - accuracy: 0.9800
# Epoch 74/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9800
# Epoch 75/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 76/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9600
# Epoch 77/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9600
# Epoch 78/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1434 - accuracy: 0.9600
# Epoch 79/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9600
# Epoch 80/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 81/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0656 - accuracy: 1.0000
# Epoch 82/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0681 - accuracy: 0.9800
# Epoch 83/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9800
# Epoch 84/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 85/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 86/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1134 - accuracy: 0.9800
# Epoch 87/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9400
# Epoch 88/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 89/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9400
# Epoch 90/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0762 - accuracy: 0.9800
# Epoch 91/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9800
# Epoch 92/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1085 - accuracy: 0.9800
# Epoch 93/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 94/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0629 - accuracy: 1.0000
# Epoch 95/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0645 - accuracy: 0.9800
# Epoch 96/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1069 - accuracy: 0.9600
# Epoch 97/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1041 - accuracy: 0.9800
# Epoch 98/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1223 - accuracy: 0.9800
# Epoch 99/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1379 - accuracy: 0.9800
# Epoch 100/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 101/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 102/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0910 - accuracy: 0.9600
# Epoch 103/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9600
# Epoch 104/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 105/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0869 - accuracy: 0.9800
# Epoch 106/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0632 - accuracy: 0.9800
# Epoch 107/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 108/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0717 - accuracy: 0.9600
# Epoch 109/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 110/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9800
# Epoch 111/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 112/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9400
# Epoch 113/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9800
# Epoch 114/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 115/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0696 - accuracy: 0.9600
# Epoch 116/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9800
# Epoch 117/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 118/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1406 - accuracy: 0.9600
# Epoch 119/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0653 - accuracy: 0.9800
# Epoch 120/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1035 - accuracy: 0.9600
# Epoch 121/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0456 - accuracy: 0.9800
# Epoch 122/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 123/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9600
# Epoch 124/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9600
# Epoch 125/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 126/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 127/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0733 - accuracy: 0.9800
# Epoch 128/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 129/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 130/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 131/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 132/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 133/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9800
# Epoch 134/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 135/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0464 - accuracy: 1.0000
# Epoch 136/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9800
# Epoch 137/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1485 - accuracy: 0.9800
# Epoch 138/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 139/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 140/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.9800
# Epoch 141/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 142/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0588 - accuracy: 1.0000
# Epoch 143/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 144/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 145/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 146/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0791 - accuracy: 0.9800
# Epoch 147/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9800
# Epoch 148/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9800
# Epoch 149/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 150/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 151/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 152/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 153/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9800
# Epoch 154/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 155/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 156/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9800
# Epoch 157/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 158/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0687 - accuracy: 0.9800
# Epoch 159/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9600
# Epoch 160/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 161/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9800
# Epoch 162/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 163/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.9800
# Epoch 164/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9800
# Epoch 165/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 166/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0691 - accuracy: 0.9600
# Epoch 167/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 168/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 169/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9600
# Epoch 170/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 171/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9800
# Epoch 172/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9800
# Epoch 173/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 174/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9800
# Epoch 175/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 176/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 177/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 178/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9800
# Epoch 179/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 180/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 0.9800
# Epoch 181/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0772 - accuracy: 0.9800
# Epoch 182/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 183/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 184/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0927 - accuracy: 0.9800
# Epoch 185/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 186/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 187/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9800
# Epoch 188/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 189/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9800
# Epoch 190/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 191/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 192/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 193/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9800
# Epoch 194/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 195/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 196/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1154 - accuracy: 0.9600
# Epoch 197/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 198/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9800
# Epoch 199/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0704 - accuracy: 0.9800
# Epoch 200/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 201/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 202/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 203/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9800
# Epoch 204/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 205/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 206/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 207/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 208/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 209/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 210/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 211/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9800
# Epoch 212/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 213/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 214/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 215/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 216/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0490 - accuracy: 0.9800
# Epoch 217/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 218/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 219/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 220/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 221/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 222/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 223/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9800
# Epoch 224/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 225/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 226/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0637 - accuracy: 0.9800
# Epoch 227/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 228/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 229/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9800
# Epoch 230/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0836 - accuracy: 0.9600
# Epoch 231/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 232/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0567 - accuracy: 0.9800
# Epoch 233/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9800
# Epoch 234/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 235/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 236/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 237/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 238/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 239/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 240/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 241/300
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 242/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 243/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 244/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 245/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 246/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.9800
# Epoch 247/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 248/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 249/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0334 - accuracy: 0.9800
# Epoch 250/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 251/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 252/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 253/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 254/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 255/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 256/300
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 1.0000
# Epoch 257/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 258/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 259/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 260/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 261/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0413 - accuracy: 0.9800
# Epoch 262/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 263/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 264/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 265/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 266/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 267/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 268/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9800
# Epoch 269/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 270/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0726 - accuracy: 0.9800
# Epoch 271/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 272/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 273/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 274/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 275/300
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 276/300
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0429 - accuracy: 0.9800
# Epoch 277/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9800
# Epoch 278/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 0.9800
# Epoch 279/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 280/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 281/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 282/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 283/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 284/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 285/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 286/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9800
# Epoch 287/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 288/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 289/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 290/300
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0266 - accuracy: 0.9800
# Epoch 291/300
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 292/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 293/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 294/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0547 - accuracy: 0.9800
# Epoch 295/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 296/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 297/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 298/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 0.9800
# Epoch 299/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0253 - accuracy: 0.9800
# Epoch 300/300
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
#
#
# **************************************************
#
# Model Created Successfully!
